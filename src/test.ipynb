# %%
import pandas as pd 
import numpy 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../odor_sim_assets/odor_tracking_vel_20250410_164720.csv')

# %%
plt.plot(df.timestamp,df.odor_concentration)

# %%
plt.scatter(df.x, df.y, c=df.odor_concentration)
plt.colorbar()
plt.xlim(-4,4)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)
